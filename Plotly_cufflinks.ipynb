# %% [markdown]
# 1. Import the stuff for plotly

# %%
import cufflinks as cf

# %%
from plotly.offline import plot,iplot,init_notebook_mode,download_plotlyjs

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Plot y=x**2 with plotly

# %%
x = np.arange(1,11)
y = x**2
df = pd.DataFrame({'x':x,'y':y})

# %%
df
# Out:
#     x    y
# 0   1    1
# 1   2    4
# 2   3    9
# 3   4   16
# 4   5   25
# 5   6   36
# 6   7   49
# 7   8   64
# 8   9   81
# 9  10  100

# %%
# %matplotlib inline

# %%
df.iplot()
# Out:
# <div>                            <div id="85e019e0-0f17-40ef-9b92-cc45f7ba008b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
3. Make a scatter plot of x and y of marker size 20

# %%
df.iplot(kind='scatter',x='x',y='y',mode='markers',size=20)
# Out:
# <div>                            <div id="f31ab179-28c7-488f-ada8-2f2d2c420225" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
q = pd.DataFrame({'A':['a','b','c'],'B':[28,58,39]})

# %% [markdown]
# 4. Make a bar plot with dataframe q

# %%
q.iplot(kind='bar',x='A',y='B')
# Out:
# <div>                            <div id="80299979-4aa1-4a42-b047-25d095278585" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# 5. Make a sum bar plot of df

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="09ac0aec-a5e1-4b1e-ab42-752f68d62b46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# 6. Make a boxplot with df

# %%
df.iplot(kind='box')

# %%
df3=pd.DataFrame({'A':[1,2,3,4,5],'B':[20,11,45,29,87],'C':[899,231,29,323,567]})

# %% [markdown]
# 7. Make a surface plot

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="69aaa976-f347-41d4-90c4-22beaaf7284e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Check out plotly documentation for colorscales

# %% [markdown]
# 8. Make a histogram with one column

# %%
df3['A'].iplot(kind='hist',bins=20)
# Out:
# <div>                            <div id="c5498798-7e68-432d-ad22-721906525a28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# 9. Make histogram of a dataframe

# %%
df3.iplot(kind='hist')
# Out:
# <div>                            <div id="e739f806-db85-491a-bc64-df395858fc16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# 10. Make a spread plot

# %%
df[['x','y']].iplot(kind='spread')
# Out:
# /Users/joyalchully/opt/anaconda3/lib/python3.8/site-packages/cufflinks/plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>                            <div id="95feb386-5ba7-457d-8cfa-7bb255abd4fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#     x    y
# 0   1    1
# 1   2    4
# 2   3    9
# 3   4   16
# 4   5   25
# 5   6   36
# 6   7   49
# 7   8   64
# 8   9   81
# 9  10  100

# %%
df3
# Out:
#    A   B    C
# 0  1  20  899
# 1  2  11  231
# 2  3  45   29
# 3  4  29  323
# 4  5  87  567

# %%
11. Make a bubble plot

# %%
df3.iplot(kind='bubble',x='B',y='C',size='A')
# Out:
# <div>                            <div id="514cebe2-23a2-4f32-b371-97d397ada944" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# 12. Make a scatter matrix

# %%
df3.scatter_matrix()
# Out:
# <div>                            <div id="1ff0b6ca-4447-4efe-ab22-c15d51965cbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # for more go to github-cufflinks-santosjorge
